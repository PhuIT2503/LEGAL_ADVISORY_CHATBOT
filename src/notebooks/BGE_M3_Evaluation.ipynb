# %%
# !pip install transformers torch faiss-cpu tqdm sqlalchemy
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.12/dist-packages (2.0.43)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)
# Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 52.6 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0

# %%
import sqlite3, json
import numpy as np
import faiss
import torch
from transformers import AutoTokenizer, AutoModel

MODEL_NAME = "models/bge-m3-law"
MAX_LENGTH = 512
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME).to(DEVICE).eval()

@torch.no_grad()
def embed_query(q: str) -> np.ndarray:
    if not q or not q.strip():
        return np.zeros((1, model.config.hidden_size), dtype="float32")
    enc = tokenizer(q, padding=True, truncation=True, max_length=MAX_LENGTH, return_tensors="pt")
    enc = {k: v.to(DEVICE) for k,v in enc.items()}
    out = model(**enc)
    last_hidden = out.last_hidden_state
    mask = enc["attention_mask"].unsqueeze(-1).expand(last_hidden.size()).float()
    summed = torch.sum(last_hidden * mask, dim=1)
    counts = torch.clamp(mask.sum(dim=1), min=1e-9)
    mean = summed / counts
    arr = mean.cpu().numpy()
    arr = arr / (np.linalg.norm(arr, axis=1, keepdims=True) + 1e-9)
    return arr.astype("float32")

def load_index(faiss_file: str):
    return faiss.read_index(faiss_file)

def fetch_docs_by_faiss_ids(conn, faiss_ids):
    if not faiss_ids:
        return []
    q_marks = ",".join("?" * len(faiss_ids))
    rows = conn.execute(
        f"SELECT faiss_id, uuid, doc_text, metadata_json FROM vectors WHERE faiss_id IN ({q_marks})",
        tuple(faiss_ids)
    ).fetchall()
    rows_map = {r[0]: {"uuid": r[1], "text": r[2], "metadata": json.loads(r[3])} for r in rows}
    return [rows_map[i] for i in faiss_ids if i in rows_map]

def rag_search(query: str, faiss_file="database/laws_bge.index", db="database/laws_bge.db", top_k=5):
    conn = sqlite3.connect(db)
    index = load_index(faiss_file)
    q_emb = embed_query(query)
    D, I = index.search(q_emb, top_k)
    ids = I[0].tolist()
    docs = fetch_docs_by_faiss_ids(conn, ids)
    conn.close()
    return [{"score": float(D[0][idx]), **docs[idx]} for idx in range(len(docs)) if idx < len(docs)]

if __name__ == "__main__":
    s = "Khoản 1 Điều 8 luật hôn nhân"
    results = rag_search(s, top_k=5)
    for i, r in enumerate(results):
        print(f"Rank {i+1} | score={r['score']:.4f} | uuid={r['uuid']}")
        print(r['text'])
        print("metadata:", r['metadata'])
        print("----")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# Rank 1 | score=0.8158 | uuid=vanban:523:chuong:523:dieu:10383:khoan:38036:diem:24714
# [Văn bản LUẬT Hôn nhân và gia đình (52/2014/QH13) - Điều 8, Khoản 1, Điểm b] Việc kết hôn do nam và nữ tự nguyện quyết định;
# metadata: {'vanban_id': 523, 'ten_vanban': 'LUẬT Hôn nhân và gia đình', 'so_hieu': '52/2014/QH13', 'ngay_ban_hanh': 'Không rõ', 'ngay_hieu_luc': '01/01/2015', 'co_quan': 'QUỐC HỘI', 'chuong_id': 523, 'ten_chuong': 'Toàn văn VBPL', 'dieu_id': 10383, 'so_dieu': '8', 'khoan_id': 38036, 'so_khoan': '1', 'diem_id': 24714, 'so_diem': 'b'}
# ----
# Rank 2 | score=0.8098 | uuid=vanban:527:chuong:527:dieu:10607:khoan:38571
# [Văn bản LUẬT Công chứng (53/2014/QH13) - Điều 8, Khoản 1] Có bằng cử nhân luật;
# metadata: {'vanban_id': 527, 'ten_vanban': 'LUẬT Công chứng', 'so_hieu': '53/2014/QH13', 'ngay_ban_hanh': 'Không rõ', 'ngay_hieu_luc': '01/01/2015', 'co_quan': 'QUỐC HỘI', 'chuong_id': 527, 'ten_chuong': 'Toàn văn VBPL', 'dieu_id': 10607, 'so_dieu': '8', 'khoan_id': 38571, 'so_khoan': '1', 'diem_id': None, 'so_diem': None}
# ----
# Rank 3 | score=0.8046 | uuid=vanban:523:chuong:523:dieu:10383:khoan:38036:diem:24715
# [Văn bản LUẬT Hôn nhân và gia đình (52/2014/QH13) - Điều 8, Khoản 1, Điểm c] Không bị mất năng lực hành vi dân sự;
# metadata: {'vanban_id': 523, 'ten_vanban': 'LUẬT Hôn nhân và gia đình', 'so_hieu': '52/2014/QH13', 'ngay_ban_hanh': 'Không rõ', 'ngay_hieu_luc': '01/01/2015', 'co_quan': 'QUỐC HỘI', 'chuong_id': 523, 'ten_chuong': 'Toàn văn VBPL', 'dieu_id': 10383, 'so_dieu': '8', 'khoan_id': 38036, 'so_khoan': '1', 'diem_id': 24715, 'so_diem': 'c'}
# ----
# Rank 4 | score=0.7941 | uuid=vanban:5:chuong:5:dieu:482:khoan:1238
# [Văn bản LUẬT số: 91/2015/QH13 (Không rõ) - Điều 8, Khoản 1] Hợp đồng.
# metadata: {'vanban_id': 5, 'ten_vanban': 'LUẬT số: 91/2015/QH13', 'so_hieu': 'Không rõ', 'ngay_ban_hanh': 'Không rõ', 'ngay_hieu_luc': None, 'co_quan': None, 'chuong_id': 5, 'ten_chuong': 'Toàn văn VBPL', 'dieu_id': 482, 'so_dieu': '8', 'khoan_id': 1238, 'so_khoan': '1', 'diem_id': None, 'so_diem': None}
# ----
# Rank 5 | score=0.7846 | uuid=vanban:455:chuong:455:dieu:6356:khoan:22923
# [Văn bản LUẬT TỐ CÁO (25/2018/QH14) - Điều 8, Khoản 1] Cản trở, gây khó khăn, phiền hà cho người tố cáo.
# metadata: {'vanban_id': 455, 'ten_vanban': 'LUẬT TỐ CÁO', 'so_hieu': '25/2018/QH14', 'ngay_ban_hanh': '12 tháng 6 năm 2018', 'ngay_hieu_luc': '01/01/2019', 'co_quan': 'QUỐC HỘI', 'chuong_id': 455, 'ten_chuong': 'Toàn văn VBPL', 'dieu_id': 6356, 'so_dieu': '8', 'khoan_id': 22923, 'so_khoan': '1', 'diem_id': None, 'so_diem': None}
# ----

# %%
# Colab: cài thư viện (chọn faiss-gpu nếu bạn chắc driver tương thích)
# !pip install -q transformers sentence-transformers faiss-cpu torch torchvision torchaudio --upgrade
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 40.6 MB/s eta 0:00:00

# %%
# ==========================================================
# Mục tiêu:
#   So sánh hiệu suất giữa:
#     1. Kết quả truy hồi ban đầu từ FAISS (embedding BGE)
#     2. Kết quả sau khi rerank bằng model BGE-reranker-v2-m3
#   Đánh giá bằng MRR@K và nDCG@K
# ==========================================================

import math, re, sqlite3, sys, time
import pandas as pd, numpy as np
from typing import List

# File test chứa danh sách câu hỏi (query) và câu trả lời đúng (ground truth)
TEST_FILE = "src/notebooks/test.xlsx"
TEST_QUERY_COL = "câu hỏi"          # Tên cột chứa câu hỏi
TEST_RELEVANT_COL = "câu trả lời"   # Tên cột chứa câu trả lời đúng
TEST_RELEVANT_IS_UUID = False       # Nếu ground truth là ID trong DB thì đặt True

# Cấu hình đánh giá
TOPK_EVAL = 5                       # Đánh giá trong top 5
FAISS_CANDIDATES_K = 30             # Lấy top 30 kết quả đầu tiên từ FAISS
RERANK_TOPK = 5                     # Sau khi rerank, chỉ lấy top 5 để đánh giá

# Đường dẫn FAISS index và database text
FAISS_FILE = "database/laws_bge.index"
DB_FILE = "database/laws_bge.db"

# Model reranker sử dụng (dùng từ HuggingFace)
RERANK_MODEL = "BAAI/bge-reranker-v2-m3"

# Cấu hình batch khi rerank
RERANK_BATCH_SIZE = 16              # Số cặp query-doc xử lý cùng lúc
RERANK_MAX_LENGTH = 512             # Giới hạn token để tránh lỗi quá dài

from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# Dùng GPU nếu có, nếu không dùng CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device for reranker:", device)

# Tải tokenizer và model từ HuggingFace
try:
    rerank_tokenizer = AutoTokenizer.from_pretrained(RERANK_MODEL)
    rerank_model = AutoModelForSequenceClassification.from_pretrained(RERANK_MODEL).to(device).eval()
except Exception as e:
    raise RuntimeError(f"Không thể load reranker '{RERANK_MODEL}'. Cần mạng hoặc model không tồn tại: {e}")

def normalize_text(s: str) -> str:
    """Chuẩn hóa text:
       - Chuyển về chữ thường
       - Loại bỏ khoảng trắng thừa"""
    if s is None: return ""
    s = str(s).lower()
    return re.sub(r'\s+', ' ', s).strip()

def parse_relevant_cell(cell, is_uuid=False):
    """Tách các câu trả lời đúng trong 1 ô Excel.
       Có thể có nhiều câu trả lời ngăn cách bởi dấu | hoặc ; hoặc xuống dòng"""
    if pd.isna(cell): return set()
    if is_uuid:
        # Nếu câu trả lời là ID trong DB
        s = str(cell)
        parts = [p.strip() for p in re.split(r'[,\|;]+', s) if p.strip()]
        return set(parts)
    # Nếu câu trả lời là text
    s = str(cell).strip()
    parts = [p.strip() for p in re.split(r'\r\n|\n|\|\||;|\|', s) if p.strip()]
    return set(parts)

def match_by_text(returned_text: str, ground_truth_texts: set, token_overlap_thresh=0.6) -> bool:
    """Kiểm tra xem văn bản trả về có khớp với ground truth không
       Dựa trên tỉ lệ trùng token (mặc định ≥ 60%)"""
    rt = normalize_text(returned_text)
    if rt == "": return False
    for gt in ground_truth_texts:
        gt_n = normalize_text(gt)
        if gt_n == "": continue

        # Nếu một chuỗi nằm trong chuỗi kia → coi là trùng
        if gt_n in rt or rt in gt_n: return True

        # Nếu trùng ≥ 60% token → coi là trùng
        rt_tokens = set(rt.split()); gt_tokens = set(gt_n.split())
        if len(gt_tokens) == 0: continue
        inter = rt_tokens.intersection(gt_tokens)
        if len(inter) / len(gt_tokens) >= token_overlap_thresh: return True
    return False

def rr_at_k_list(ranked_list, relevant_set, k):
    """Tính Reciprocal Rank (RR):
       = 1 / vị trí của phần tử đúng đầu tiên trong top-k"""
    for i, item in enumerate(ranked_list[:k], start=1):
        if item in relevant_set: return 1.0 / i
    return 0.0

def dcg_at_k_binary(ranked_list, relevant_set, k):
    """Tính DCG@k (Discounted Cumulative Gain)
       1 nếu item đúng, chia cho log2(vị trí + 1)"""
    dcg = 0.0
    for i, item in enumerate(ranked_list[:k], start=1):
        if item in relevant_set:
            dcg += 1.0 / math.log2(i + 1)
    return dcg

def idcg_binary(n_relevant, k):
    """Tính IDCG@k (DCG lý tưởng) để chuẩn hóa thành nDCG"""
    idcg = 0.0
    for i in range(1, min(n_relevant, k) + 1):
        idcg += 1.0 / math.log2(i + 1)
    return idcg

@torch.no_grad()
def rerank_scores_bge_classifier(query: str, docs: List[str],
                                 batch_size:int = RERANK_BATCH_SIZE,
                                 max_length:int = RERANK_MAX_LENGTH):
    """
    Hàm tính điểm relevance giữa query và danh sách documents.
    - Input: query (str), docs (list[str])
    - Output: mảng numpy các điểm (float32), càng cao → càng liên quan
    """
    scores = []
    for i in range(0, len(docs), batch_size):
        # Lấy 1 batch docs
        batch_docs = docs[i:i+batch_size]

        # Tokenizer chấp nhận list cặp (query, doc)
        enc = rerank_tokenizer([query]*len(batch_docs), batch_docs,
                                padding=True, truncation=True, max_length=max_length,
                                return_tensors="pt")
        enc = {k: v.to(device) for k,v in enc.items()}  # Chuyển sang GPU/CPU
        out = rerank_model(**enc)                       # Chạy model
        logits = out.logits.detach().cpu().numpy()      # Kết quả (B, num_labels)

        # Nếu model chỉ có 1 logit → lấy trực tiếp
        if logits.shape[1] == 1:
            batch_scores = logits[:,0].tolist()
        else:
            # Nếu có 2 lớp → lấy điểm lớp "positive" (index 1)
            batch_scores = logits[:,1].tolist()

        scores.extend(batch_scores)
    return np.array(scores, dtype="float32")

if TEST_FILE.lower().endswith((".xls", ".xlsx")):
    df = pd.read_excel(TEST_FILE)
else:
    df = pd.read_csv(TEST_FILE)

# Kiểm tra cột hợp lệ
if TEST_QUERY_COL not in df.columns or TEST_RELEVANT_COL not in df.columns:
    print("LỖI: Không tìm thấy cột TEST_QUERY_COL hoặc TEST_RELEVANT_COL trong file test.")
    print("Cột có trong file:", df.columns.tolist())
    sys.exit(1)

# Lấy danh sách câu hỏi và câu trả lời đúng
queries = df[TEST_QUERY_COL].astype(str).tolist()
relevant_cells = df[TEST_RELEVANT_COL].tolist()
parsed_relevants = [parse_relevant_cell(c, is_uuid=TEST_RELEVANT_IS_UUID) for c in relevant_cells]

try:
    index = load_index(FAISS_FILE)
except Exception as e:
    raise RuntimeError(f"Không thể load FAISS index từ {FAISS_FILE}: {e}")

# Biến lưu kết quả đánh giá
faiss_rrs = []; faiss_ndcgs = []
rerank_rrs = []; rerank_ndcgs = []

# Vòng lặp qua từng câu hỏi
for i, q in enumerate(queries):
    print(f"[{i+1}/{len(queries)}] Query: {q[:80]}...")
    gt_set = parsed_relevants[i]  # ground truth cho query này

    q_emb = embed_query(q)                                # Tạo embedding cho query
    D, I = index.search(q_emb, FAISS_CANDIDATES_K)        # Lấy top 30 văn bản gần nhất
    faiss_ids = I[0].tolist()

    # Lấy text của các văn bản từ database
    conn = sqlite3.connect(DB_FILE)
    faiss_docs = fetch_docs_by_faiss_ids(conn, faiss_ids)
    conn.close()

    # ĐÁNH GIÁ FAISS
    if TEST_RELEVANT_IS_UUID:
        # Nếu ground truth là ID
        faiss_ranked = [d['uuid'] for d in faiss_docs][:TOPK_EVAL]
        faiss_rr = rr_at_k_list(faiss_ranked, gt_set, TOPK_EVAL)
        dcg = dcg_at_k_binary(faiss_ranked, gt_set, TOPK_EVAL)
        idcg = idcg_binary(len(gt_set), TOPK_EVAL)
        faiss_ndcg = (dcg / idcg) if idcg>0 else 0.0
    else:
        # Nếu ground truth là text
        faiss_ranked_texts = [normalize_text(d['text']) for d in faiss_docs][:TOPK_EVAL]
        rels = [1 if match_by_text(t, gt_set) else 0 for t in faiss_ranked_texts]

        # Tính RR và nDCG
        faiss_rr = 0.0
        for pos, v in enumerate(rels, start=1):
            if v:
                faiss_rr = 1.0/pos; break
        dcg = sum((1.0 / math.log2(pos+1)) for pos, v in enumerate(rels, start=1) if v)
        idcg = idcg_binary(len(gt_set), TOPK_EVAL)
        faiss_ndcg = (dcg / idcg) if idcg>0 else 0.0

    docs_texts = [d['text'] for d in faiss_docs]  # Lấy text của các docs từ FAISS

    if len(docs_texts) == 0:
        # Nếu FAISS không trả về gì
        rerank_rr = 0.0
        rerank_ndcg = 0.0
    else:
        try:
            # Tính điểm liên quan (relevance score)
            scores = rerank_scores_bge_classifier(q, docs_texts,
                                                  batch_size=RERANK_BATCH_SIZE,
                                                  max_length=RERANK_MAX_LENGTH)
        except Exception as e:
            print(f"Reranker failed for query {i}: {e}")
            scores = np.zeros(len(docs_texts), dtype="float32")

        # Sắp xếp docs theo điểm giảm dần
        ranked_idx_scores = sorted(list(enumerate(scores)), key=lambda x: x[1], reverse=True)
        topk_idx = [idx for idx, sc in ranked_idx_scores[:RERANK_TOPK]]

        if TEST_RELEVANT_IS_UUID:
            rerank_ranked = [faiss_docs[idx]['uuid'] for idx in topk_idx]
            rerank_rr = rr_at_k_list(rerank_ranked, gt_set, TOPK_EVAL)
            dcg = dcg_at_k_binary(rerank_ranked, gt_set, TOPK_EVAL)
            idcg = idcg_binary(len(gt_set), TOPK_EVAL)
            rerank_ndcg = (dcg / idcg) if idcg>0 else 0.0
        else:
            rerank_topk_texts = [normalize_text(docs_texts[idx]) for idx in topk_idx]
            rels = [1 if match_by_text(t, gt_set) else 0 for t in rerank_topk_texts]
            rerank_rr = 0.0
            for pos, v in enumerate(rels, start=1):
                if v:
                    rerank_rr = 1.0/pos; break
            dcg = sum((1.0 / math.log2(pos+1)) for pos, v in enumerate(rels, start=1) if v)
            idcg = idcg_binary(len(gt_set), TOPK_EVAL)
            rerank_ndcg = (dcg / idcg) if idcg>0 else 0.0

    # Lưu kết quả từng query
    faiss_rrs.append(faiss_rr)
    faiss_ndcgs.append(faiss_ndcg)
    rerank_rrs.append(rerank_rr)
    rerank_ndcgs.append(rerank_ndcg)

print("==== SUMMARY ====")
print("FAISS-only MRR@{} = {:.6f}, nDCG@{} = {:.6f}".format(
    TOPK_EVAL, np.mean(faiss_rrs), TOPK_EVAL, np.mean(faiss_ndcgs)))
print(f"RERANKER ({RERANK_MODEL}) MRR@{TOPK_EVAL} = {np.mean(rerank_rrs):.6f}, nDCG@{TOPK_EVAL} = {np.mean(rerank_ndcgs):.6f}")
# Out:
# Device for reranker: cuda
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/795 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# [1/737] Query: Thu giữ tiền giả...
# [2/737] Query: 8 trường hợp bị thu hồi đất...
# [3/737] Query: Công an mời gia đình nữ sinh tử vong vì tai nạn giao thông ở Vĩnh Long làm việc...
# [4/737] Query: Bình Định sớm thu hồi 5,3 tỷ đồng chi sai khi mở rộng quốc lộ 1A...
# [5/737] Query: người hút thuốc lá tại khu vui chơi dành cho trẻ em thì bị xử phạt như thế nào?...
# [6/737] Query: Truy tố 28 bị can trong đường dây “chạy án” liên quan nhiều thẩm phán, kiểm sát ...
# [7/737] Query: Xin hỏi, có được sử dụng căn cước điện tử làm thủ tục hành chính không?
# ...
# [8/737] Query: Xin hỏi con cái không chăm sóc, nuôi dưỡng bố mẹ lúc già yếu thì có được hưởng d...
# [9/737] Query: Có được ủy quyền cho người khác sử dụng tài khoản thanh toán của mình không?...
# [39/737] Query: Những tình khúc bất hủ sẽ vang lên tại Nhà hát Lớn Hà Nội...
# [40/737] Query: Bạn Hữu Tiếp cho biết: Tháng 6/2018, tôi ký hợp đồng lao động không xác định thờ...
# [41/737] Query: Xin hỏi, sinh viên có thể bị đình chỉ học trong những trường hợp nào?...
# [42/737] Query: Theo quy định mới, thời gian làm việc của giáo viên như thế nào?...
# [43/737] Query: Tôi có nộp hồ sơ đăng ký doanh nghiệp và đã được chấp thuận. Tuy nhiên tôi không...
# [44/737] Query: Chú rể hành hung lái xe ben trong ngày rước dâu: Có thể xử lý hình sự?...
# [45/737] Query: Đột ngột bị chuyển công việc khác hợp đồng, đúng luật không?...
# [46/737] Query: Vụ cắn chảy máu tay rồi bôi vào cảnh sát: Có thể xử lý thêm tội danh?
#
# Công an h...
# [47/737] Query: Xin hỏi, khi chuyển mục đích sử dụng đất thì thời hạn sử dụng đất được quy định ...
# [48/737] Query: Đăng ký cư trú cho người chưa thành niên bằng cách nào?...
# [49/737] Query: Gia đình ông Cường được ông nội chia cho 250 m2 đất, khi làm xong bìa đỏ thì gia...
# [50/737] Query: Theo phản ánh của bà Thị Hạnh (TPHCM), Phòng Tài chính - Kế hoạch được UBND quận...
# [51/737] Query: Bảo đảm ngành y tế phát triển bền vững...
# [52/737] Query: Xin hỏi, những người có thẩm quyền xử lý kỷ luật lao động được quy định thế nào?...
# [53/737] Query: Khi nào bất động sản mới đủ điều kiện đưa vào kinh doanh?
# ...
# [54/737] Query: Ông Hoàng muốn thuê lại lao động nước ngoài về làm giáo viên dạy Yoga, nhưng the...
# [55/737] Query: Google Maps sắp bổ sung tính năng được mong đợi từ lâu...
# [56/737] Query: Bà Đ.N.B. Ngọc (Tây Ninh) đã đạt 5 năm Chiến sĩ thi đua cơ sở (2019-2023).
# Năm 2...
# [57/737] Query: Mức tiền thưởng Huân chương các loại từ tháng 7.2025 được quy định thế nào?
# ...
# [58/737] Query: Xin hỏi, chở đào, quất cồng kềnh bằng xe máy dịp Tết gây mất an toàn giao thông ...
# [59/737] Query: Samsung thay đổi biểu tượng pin trên One UI 8.5...
# [60/737] Query: Theo phản ánh của ông Tùng Linh, Khoản 2 Điều 16 Luật Nhà ở 2023 quy định:
# "2. B...
# [61/737] Query: Để đăng ký tạm trú, người thuê trọ cần chuẩn bị hồ sơ gì?...
# [62/737] Query: Môn cạnh tranh cao; môn nhu cầu cao nhưng ít người ứng tuyển ...
# [63/737] Query: Thời gian hưởng chế độ ốm đau...
# [64/737] Query: Xin hỏi, người điều khiển phương tiện tham gia giao thông có được vượt xe cứu th...
# [65/737] Query: Chỉ thu hồi CCCD sau khi đã cấp thẻ căn cước...
# [66/737] Query: Đất xây dựng khu chung cư được quy định thế nào?
# ...
# [67/737] Query: Trường hợp nào cán bộ vi phạm pháp luật nhưng thoát tội?...
# [68/737] Query: Cha mẹ tặng cho nhà để thờ cúng, đem bán được không?...
# [69/737] Query: Doanh nghiệp đamg tạm ngưng kinh doanh có bắt buộc phải cập nhật CCCD tr...
# [341/737] Query: Đề nghị tòa soạn cho biết, việc phát triển nhà ở theo dự án đầu tư xây dựng nhà ...
# [342/737] Query: Người lao động được cho thuê lại vi phạm kỷ luật lao động thì ai có quyền xử lý ...
# [343/737] Query: Người bị xử lý hành chính có phải thôi tham gia lực lượng bảo vệ an ninh, trật t...
# [344/737] Query: Thay đổi CCCD, người lao động có 2 mã số BHXH thì làm sao?...
# [345/737] Query: Mở rộng diện đóng BHXH bắt buộc...
# [346/737] Query: Tuyển giáo viên tại TP.HCM: Môn nào có tỷ lệ cạnh tranh cao?...
# [347/737] Query: Hợp đồng mua bán điện phục vụ mục đích sinh hoạt được quy định thế nào?...
# [348/737] Query: Nhiều iPhone đời cũ không còn sử dụng được iCloud...
# [349/737] Query: Ứng dụng AI vào lưới điện thông minh: Động lực mới cho phát triển bền vững...
# [350/737] Query: Sau ly hôn, vợ có phải trả nợ cho chồng?
#
# Một phụ nữ ở thành phố Mỹ Tho, tỉnh Ti...
# [351/737] Query: Trung Quốc tạo ra pin xe điện sạc 10 phút chạy 478 km...
# [352/737] Query: Cách xác định tiền lương để tính hưởng trợ cấp tinh giản biên chế như thế nào?...
# [353/737] Query: Bị tước giấy phép lái xe nhưng vẫn chạy, bị xử lý sao?...
# [354/737] Query: Sau khi Tôi đã chọn các sản phẩm cho vào đơn hàng, nếu tôi nhận thấy không cần m...
# [355/737] Query: Hiện tại, công ty chúng tôi đang hoạt động tại trụ sở chính tại Thành phố Hà Nội...
# [356/737] Query: Người hoạt động không chuyên trách ở thôn, tổ dân phố được hưởng chế độ phụ cấp ...
# [357/737] Query: Công ty thu tiền môi giới xuất khẩu lao động của người lao động thì có bị xử phạ...
# [358/737] Query: XEM GIÚP SỐ HỒ SƠ H29.13-250520-4417 TÔI ĐĂNG KÝ NHẬN BƯU ĐIỆN ĐƯỢC CHƯA Ạ, TÔI ...
# [359/737] Query: Người cao tuổi nào được trợ cấp xã hội hàng tháng?
# ...
# [360/737] Query: Côn Đảo: Lần đầu tiên thực hiện phẫu thuật nội soi cho bệnh nhân...
# [361/737] Query: Phó chủ tịch huyện bị tố kỳ kèo phần trăm: Vì sao phải tìm người đăng clip?
#
# Ngà...
# [362/737] Query: Cơ hội sở hữu MacBook giá rẻ sắp thành hiện thực...
# [363/737] Query: Theo quy định mới, điều kiện để được làm tổng giám đốc (giám đốc) ngân hàng thế ...
# [364/737] Query: Hình thức kiểm tra, giám sát của quân nhân, công nhân, viên chức quốc phòng, ngư...
# [365/737] Query: Văn phòng công chứng được lựa chọn tên gọi...
# [366/737] Query: Các nội dung diễn tập của lực lượng tham gia bảo vệ an ninh, trật tự ở cơ sở thế...
# [367/737] Query: Công ty em là cty TNHH có 2 thành viên góp vốn được thành lập vào năm 2022. Các ...
# [368/737] Query: Người dân muốn chuyển mục đích sử dụng đất cần phải đáp ứng điều kiện gì?...
# [369/737] Query: NBC News: Chính phủ Mỹ sớm sa thải nhân viên liên bang...
# [456/737] Query: Người đàn ông bị lừa 2 tỷ đồng vì cài ứng dụng EVN giả mạo...
# [457/737] Query: Theo quy định mới, người có giấy phép lái xe bị trừ hết điểm có được lái xe khôn...
# [458/737] Query: Làm ngơ trước vi phạm lao động, Apple hứng bão chỉ trích khiến iPhone 17 'mất đi...
# [459/737] Query: Ông Đức thi tuyển vào vị trí Thư viện viên hạng IV, mã số V.10.02.07.
# Ông đã hoà...
# [460/737] Query: Bà Thị Bích Duyên (Kiên Giang) đã có bằng cử nhân ngôn ngữ Anh, hệ chính quy, nh...
# [461/737] Query: Vụ dự án nuôi bò ở Đắk Lắk: Đề nghị doanh nghiệp hoàn trả 55 tỷ đồng trong năm 2...
# [462/737] Query: "Sa lưới" sau 43 năm, nghi phạm vụ sát hại 6 người có thể bị xử lý ra sao?...
# [463/737] Query:  nếu đi làm ngày lễ Quốc khánh 2.9, thì có được nghỉ bù vào ngày khác không?...
# [464/737] Query: Những ai không được nhận con nuôi?...
# [465/737] Query: Lấy nhân dân làm trung tâm, khu dân cư là địa bàn trọng điểm để triển khai hoạt ...
# [466/737] Query: Nộp đơn ly hôn ở đâu?...
# [467/737] Query: Hậu quả pháp lý nào chờ đón chủ doanh nghiệp "viết hộ" hóa đơn VAT?
#
# Thông thườn...
# [468/737] Query: Hợp đồng góp vốn bằng nhà ở có phải công chứng hoặc chứng thực không?...
# [469/737] Query: Công ty tôi muốn đăng ký tạm ngừng kinh doanh từ ngày 30/4/2022 đến ngày 30/5/20...
# [470/737] Query: Thẻ ngân hàng phải đáp ứng điều kiện gì để có thể thanh toán trực tuyến trên Cổn...
# [471/737] Query: Khai báo tạm trú dễ dàng trên VNeID ...
# [472/737] Query: Theo quy định mới, giáo viên tiểu học phải bắt buộc có chứng chỉ nghiệp vụ sư ph...
# [473/737] Query: Ốp lưng cho iPhone 17 liệu có còn cần thiết?...
# [474/737] Query: Xin hỏi, thu ngân sách từ đất đai theo Luật Đất đai 2024 bao gồm những khoản nào...
# [475/737] Query: Ông Hoàng Trung (Cần Thơ) làm giám đốc công ty cổ phần thuộc vùng I, nghỉ việc t...
# [476/737] Query: AI giúp người trẻ chủ động tìm việc ra sao?...
# [477/737] Query: Khi nào sửa chữa căn hộ chung cư không phải xin phép?...
# [478/737] Query: Nguyên tắc xác định mức phạt tiền cụ thể đối với một hành vi vi phạm hành chính ...
# [479/737] Query: Để thông báo nhà ở hình thành trong tương lai đủ điều kiện được bán, cần chuẩn b...
# [480/737] Query: Sở GD-ĐT TPHCM thông tin về trường hợp bố trí học vào thứ bảy...
# [481/737] Query: Án treo, xét xử sao cho đúng: Luật và hướng dẫn phải rõ ràng để áp dụng minh bạc...
# [482/737] Query: Tôi nghe nói, từ giữa tháng 9.2023, cảnh sát giao thông có quyền mặc thường phục...
# [483/737] Query: Các chuyên gia trấn an người dùng sau sự cố dữ liệu với CIC...
# [484/737] Query: Xin hỏi, hiện nay, người khuyết tật đặc biệt nặng có được ưu tiên khám bệnh, chữ...
# [485/737] Query: Hành vi ngược đãi người lao động sẽ bị phạt thế nào?
# ...
# [486/737] Query: Thả cá thể Rùa Đầu to quý hiếm về môi trường tự nhiên...
# [487/737] Query: Kê khai, nộp hồ sơ đăng ký xe thế nào?...
# [488/737] Query: Cần bao nhiêu ngày làm việc mới đủ tiền mua iPhone 17 Pro?...
# [489/737] Query: Thượng viện bác đề xuất ngân sách tạm thời, Chính phủ Mỹ chuẩn bị đóng cửa...
# [490/737] Query: Người khuyết tật nặng, đặc biệt nặng được hỗ trợ kinh phí chăm sóc thế nào?...
# [491/737] Query: Hội đồng Bảo an Liên hợp quốc họp khẩn về xung đột Gaza: Khó có đột phá do bất đ...
# [492/737] Query: 50 tỷ đồng làm kè chống sạt lở bảo vệ bờ biển...
# [493/737] Query: Vừa qua, bạn đọc Phạm Văn Dương (SN 1984, ngụ tại xã Long Tân, huyện Dầu Tiếng, ...
# [494/737] Query: trường hợp xe máy bị tịch thu, nhưng không có số máy thì có được đăng ký xe khôn...
# [495/737] Query:  Khi nào thì được chở người trên xe tải?...
# [496/737] Query: Xảy ra cháy nổ ở bãi giữ xe, trách nhiệm thuộc về ai?
# ...
# [497/737] Query: Việc bảo đảm điều kiện hoạt động công đoàn được quy định thế nào?...
# [498/737] Query: Xin hỏi, từ năm 2024, điều kiện để cá nhân được phép khám bệnh, chữa bệnh được q...
# [499/737] Query: Đập vỡ kính ô tô để đánh ghen: Hành vi nóng nảy, có thể đối diện án phạt
#  tù
#
# Ng...
# [500/737] Query: Người lao động vào làm việc có bắt buộc phải nộp hồ sơ, giấy tờ cá nhân?...
# [501/737] Query: Theo Luật Trật tự, an toàn giao thông đường bộ 2024, những chỗ nào không được dừ...
# [502/737] Query: Khi nào mới bị ngừng, giảm mức cung cấp điện?...
# [503/737] Query: Hiến tạng tại Hà Nội...
# [504/737] Query: Phố lồng đèn Lương Nhữ Học rực rỡ sắc màu đón Trung thu...
# [505/737] Query: Tài sản thừa kế nào phải nộp thuế thu nhập cá nhân?...
# [506/737] Query: Vbee khẳng định vị thế AI Voice 'Make in Vietnam' tại AWS Cloud Day 2025...
# [507/737] Query: Sở Y tế tỉnh Khánh Hòa bác tin mở "lớp học bán trú cho người cao tuổi"...
# [508/737] Query: Mức phạt lỗi chạy xe ô tô chậm theo luật mới...
# [509/737] Query: Đóng BHXH tự nguyện có được hưởng chế độ thai sản?...
# [510/737] Query: Cảnh báo thông tin không đúng về sắp xếp các cơ sở giáo dục đại học...
# [511/737] Query: Việc giám định sức khỏe nghĩa vụ quân sự được quy định thế nào?
# ...
# [512/737] Query: Ông Tùng (Đồng Nai) là viên chức, ký hợp đồng ngày 1/3/2021, thời hạn 3 năm.
# The...
# [513/737] Query: Khởi tố 3 đối tượng liên quan vụ mua bán trái phép hóa đơn hơn 11 tỷ đồng...
# [514/737] Query: Tổng Bí thư Tô Lâm đánh trống khai giảng năm học 2025-2026...
# [515/737] Query: Người nào được hiến tinh trùng, hiến noãn trong mang thai hộ vì mục đích nhân đạ...
# [558/737] Query: Công ty tôi mới ký hợp đồng lao động với một lao động là người nước ngoài. Xin h...
# [559/737] Query: Sự khác nhau giữa BHXH bắt buộc và tự nguyện...
# [560/737] Query: Doanh nghiệp có vốn đầu tư nước ngoài có giấy phép đầu tư hết hạn ngày 31/12/202...
# [561/737] Query:  Lao động nữ phá thai được hưởng chế độ thai sản thế nào?...
# [562/737] Query: Giãn cách xã hội theo Chỉ thị 16 có những nội dung gì?...
# [563/737] Query: Phát động Giải Báo chí toàn quốc về phòng, chống HIV/AIDS năm 2025...
# [564/737] Query: Công ty CP S. thường gửi văn bản cho cơ quan nhà nước bằng bản giấy, đóng dấu đỏ...
# [565/737] Query: Trong quá trình tư vấn pháp luật, Văn phòng Luật sư tư vấn N.H (Cần Thơ) gặp m...
# [566/737] Query: Thanh tra chuyên ngành đối với cơ sở giáo dục đại học, trường cao đẳng sư phạm đ...
# [567/737] Query: Lợi ích của thẻ căn cước...
# [568/737] Query: Bạn Đình Hưng hỏi: hiện tôi là Sĩ quan Thông tin của Quân đội nhân dân Việt Nam,...
# [569/737] Query: Thủ tục xin hoãn nghĩa vụ quân sự khi đang học đại học, cao đẳng...
# [570/737] Query: Người đang làm trong khu công nghiệp được thuê nhà lưu trú công nhân có được cho...
# [571/737] Query: Rò rỉ hình ảnh thực tế về One UI 8.5...
# [572/737] Query: Điều kiện đăng ký xe, cấp biển số...
# [573/737] Query: Người sử dụng lao động có phải bảo vệ bí mật, danh dự, uy tín, nhân phẩm, an toà...
# [574/737] Query: Xin hỏi, giáo viên mầm non phải dạy bao nhiêu giờ trong một ngày?...
# [575/737] Query: Vi phạm khai báo tạm trú sẽ phạt tiền từ 20 triệu đồng đến 40 triệu đồng...
# [576/737] Query: Có phải tất cả các sản phẩm dịch vụ thông tin đều mất phí hay không?...
# [577/737] Query: Ông L có công văn giới thiệu của Bộ Nội vụ gửi địa phương hồi 2019 do đáp ứng đủ...
# [578/737] Query: các giấy tờ để được cấp hộ chiếu phổ thông ở nước ngoài gồm những loại nào?
# ...
# [579/737] Query: Xin hỏi, những trường hợp nào sẽ bị thu hồi đất do vi phạm pháp luật về đất đai ...
# [580/737] Query: Từ vụ gã nghiện sát hại CSCĐ: Vì sao "ngáo đá" không được miễn trách nhiệm?...
# [581/737] Query: Theo quy định mới, những hành vi vi phạm nào khi điều khiển xe gắn máy sẽ bị tịc...
# [582/737] Query: Sẵn sàng bước vào năm học mới...
# [583/737] Query: Hàng loạt sai phạm tại nha khoa Tuyết Chinh...
# [584/737] Query: Hong Kong và Macau nâng cảnh báo siêu bão Ragasa lên mức cao nhất...
# [585/737] Query: Năm 2024 lịch khám nghĩa vụ quân sự được thực hiện vào thời điểm nào?
# ...
# [586/737] Query: Pháp luật quy định như thế nào về các căn cứ để đánh giá nhãn hiệu hàng hóa bị l...
# [587/737] Query: Hướng dẫn cách chuyển đổi sổ đỏ hộ gia đình sang tên cá nhân...
# [588/737] Query: Mức trợ cấp xã hội cao nhất của người khuyết tật đặc biệt nặng là bao nhiêu?...
# [589/737] Query: Người từng bị Covid-19 có thể mắc hoại tử xương...
# [590/737] Query: Thế hệ iPhone 17 cho đặt mua trước tại Việt Nam, nhiều ưu đãi tặng kèm máy...
# [591/737] Query: Duy trì số thuê bao bằng cách nào?...
# [592/737] Query: Giải cứu 2 trường hợp bị bắt cóc online...
# [593/737] Query: Xin hỏi, việc dạy tiếng Việt cho trẻ em dân tộc thiểu số trước khi vào lớp một g...
# [594/737] Query: Đối tượng phải nộp thuế thu nhập cá nhân...
# [595/737] Query: Xin hỏi, mở cửa hàng tạp hóa có bắt buộc phải đăng ký hộ kinh doanh không. Nếu k...
# [596/737] Query: Năm 2025 giấy phép lái xe B1, B2 được cấp đổi sang loại bằng nào?...
# [597/737] Query: Xin hỏi, có được sửa đổi, bổ sung thỏa ước lao động tập thể không. Việc thực hiệ...
# [598/737] Query: Tôi đang chờ cấp lại thẻ bảo hiểm y tế. Xin hỏi, trong thời gian chờ cấp lại thẻ...
# [599/737] Query: Google sao chép phụ kiện đắt đỏ đến khó tin của iPhone 17...
# [600/737] Query: Trường hợp nào thì được đóng bảo hiểm xã hội tự nguyện?
# ...
# [601/737] Query: Bạn đọc Y Rô Buôn Krông, ở xã Ea Hiu, huyện Krông Pắc, tỉnh Đắk Lắk hỏi: Đề nghị...
# [602/737] Query: Quy định về việc doanh nghiệp có quyền tự do kinh doanh những ngành, nghề mà luậ...
# [603/737] Query: Thời điểm xác lập quyền sở hữu nhà ở theo quy định mới thế nào?
# ...
# [604/737] Query: Mức đóng bảo hiểm tự nguyện để được hưởng thai sản...
# [605/737] Query: Bạn đọc Nguyễn Văn Thực ở phường Hiệp Tân, thị xã Hòa Thành, tỉnh Tây Ninh, hỏi:...
# [606/737] Query: Xin hỏi, nếu lái xe máy mà có nồng độ cồn trong máu trên 0,25 miligam đến 0,4 mi...
# [607/737] Query: Nữ hoàng nội y' Ngọc Trinh bị khởi tố khung hình phạt nào?...
# [608/737] Query: Xin hỏi, cá nhân gọi điện quấy rối đường dây nóng của cơ quan, tổ chức có thể bị...
# [609/737] Query: Tháo gỡ vướng mắc liên quan dự án cấp nước cho Khu kinh tế Vũng Áng...
# [610/737] Query: xe hết niên hạn sử dụng có bị thu hồi giấy chứng nhận đăng ký xe không, nếu phải...
# [611/737] Query: Galaxy S26 Ultra chỉ hỗ trợ tốc độ sạc nhanh 45W?...
# [612/737] Query: Triệt phá nhóm tội phạm sử dụng công nghệ cao quy mô cả nước...
# [613/737] Query: Cách tính lương hưu hằng tháng theo quy định mới như thế nào?
# ...
# [614/737] Query: Xin hỏi, theo quy định mới, từ tháng 6.2024, trường hợp nào sẽ bị coi là vi phạm...
# [615/737] Query: Vụ nổ súng ở Sầm Sơn: Có căn cứ xử lý tội giết người?
#
# trưa 18/7, Nguyễn Thái Bằ...
# [616/737] Query: Trường THCS - THPT Tân Bằng đạt chuẩn quốc gia trước thềm năm học mới...
# [617/737] Query: Nới lỏng điều kiện nhập quốc tịch Việt Nam...
# [618/737] Query: Xin hỏi, theo quy định mới, tổng thời gian đóng bảo hiểm thất nghiệp (BHTN) được...
# [619/737] Query: Cà Mau: Tạm giữ nghi phạm vụ cháy chợ hơn 20 tỷ đồng...
# [620/737] Query: Khởi tố 10 đối tượng làm giả hồ sơ, chiếm đoạt hàng trăm triệu đồng tiền bảo hiể...
# [621/737] Query: Nguyên tắc thực hiện chính sách, chế độ khi sắp xếp bộ máy được quy định thế nào...
# [622/737] Query: Các lỗi bị tịch thu ô tô nếu vi phạm...
# [623/737] Query: Các yếu tố cấu thành tội loạn luân...
# [624/737] Query: Pháp luật quy định thế nào về 'thỏa thuận chấm dứt hợp đồng lao động'?...
# [625/737] Query: Tôi muốn hỏi quy trình công chứng điện tử trực tuyến theo Nghị định 104/2025/NĐ-...
# [626/737] Query: Người tham gia lực lượng bảo vệ an ninh, trật tự ở cơ sở tại TPHCM được đóng BHX...
# [627/737] Query: Bạn Tiên hỏi: Tôi đã làm thẻ căn cước số 09.......... và đã có định danh điện...
# [628/737] Query: Trưởng thôn có vai trò gì khi cho thôi đối với người tham gia bảo vệ an ninh, tr...
# [629/737] Query: Năm 2017, bà Huỳnh Như (Kiên Giang) có bằng dược sĩ trung cấp hệ vừa làm vừa học...
# [630/737] Query: Vợ ông Lê Tùng Vân chết, giải quyết vụ án ra sao?...
# [631/737] Query: Người lao động sinh con ngày 18/12/2023, trong tháng 12 có 12 ngày nghỉ thai sản...
# [632/737] Query: Công ty cổ phần X (không phải công ty đại chúng) dự định tăng vốn điều lệ bằng c...
# [633/737] Query: The Men trở lại mạnh mẽ với podcast kể chuyện âm nhạc...
# [634/737] Query: Cách xin mẫu CT08...
# [635/737] Query: Đà Nẵng tăng tốc đầu tư, nâng chuẩn trường lớp vùng khó khăn...
# [636/737] Query: Khi nào bắt buộc phải đấu giá, đấu thầu?...
# [637/737] Query: Trường hợp nào thì phải cho thôi tổ trưởng tổ bảo vệ an ninh, trật tự ở cơ sở....
# [638/737] Query: Giáo viên đón đầu xu thế dạy học bằng tiếng Anh...
# [639/737] Query: Mức phụ cấp của Tổ trưởng Tổ dân phố được quy định thế nào?...
# [640/737] Query: Thành lập như Mái ấm Hoa Hồng, phải đáp ứng những tiêu chí nào?...
# [641/737] Query: Quảng Ngãi: Triệt xóa tụ điểm mại dâm núp bóng massage...
# [642/737] Query: Ông Thành (Nam Định) có một bất động sản là trại heo vẫn đang hoạt động.
# Nay, ôn...
# [643/737] Query: Sở GD-ĐT Hà Nội phản hồi về việc chậm trễ cho học sinh nghỉ học khi ngập lụt...
# [644/737] Query: Đề nghị tòa soạn cho biết ngoài trường hợp cấp cứu thì những trường hợp nào ngườ...
# [645/737] Query: Quảng Ngãi: Tiêu hủy 800 con vịt nhiễm cúm A/H5N1...
# [646/737] Query: Căn cứ đóng BHXH bắt buộc...
# [647/737] Query: Vì sao chuyển đổi số trong giáo dục chưa chuyển biến rõ rệt?...
# [648/737] Query: Việc gia hạn nộp thuế thu nhập doanh nghiệp trong năm 2025 được quy định thế nào...
# [649/737] Query: Người hoạt động không chuyên trách ở cấp xã khi bị kỷ luật có bị hạ bậc lương kh...
# [650/737] Query: Thửa đất của ông Nguyễn Nguyền (Thừa Thiên Huế) được cấp Giấy chứng nhận quyền s...
# [651/737] Query: Tạm giữ khẩn cấp 3 đối tượng trộm gần 300 gốc sâm Ngọc Linh...
# [652/737] Query: Hiệu trưởng trường công lập thì có được quản lí, điều hành cơ sở dạy thêm ngoài ...
# [653/737] Query: TPHCM: Khắc phục bất ổn về nhân sự của các trung tâm ngoại ngữ, tin học...
# [654/737] Query: Áp thấp nhiệt đới đang mạnh lên thành bão số 11 tiến vào Biển Đông...
# [655/737] Query: Hồ sơ, thủ tục xin miễn, giảm học phí gồm những gì?...
# [656/737] Query: Người được đặc xá có đương nhiên được xóa án tích?...
# [657/737] Query: Xin hỏi, quy định về việc công bố báo cáo tài chính giữa năm của doanh nghiệp nh...
# [658/737] Query: Hội đồng nghĩa vụ quân sự cấp xã có những nhiệm vụ gì?
# ...
# [659/737] Query: Điều tra vụ một người bị đánh nghi do tranh địa bàn cứu hộ trên cao tốc...
# [660/737] Query: Tôi được công ty tăng lương sau 2 năm làm việc, nhưng công ty yêu cầu tôi làm th...
# [661/737] Query: Nhà xây không phép, ly hôn chia tài sản thế nào?...
# [662/737] Query: Đất bị lấn chiếm nhưng chưa đòi, 30 năm sau có kiện được không?...
# [663/737] Query: Quân nhân, công nhân, viên chức quốc phòng, người lao động được bàn và quyết địn...
# [664/737] Query: Mức phạt vi phạm giao thông từ 2 - 3 triệu đồng mà người chạy xe máy cần biết...
# [665/737] Query: Galaxy S26 Ultra sẽ trang bị công nghệ đột phá so với iPhone 17 Pro...
# [666/737] Query: Những lưu ý khi làm thủ tục tặng cho nhà đất...
# [667/737] Query: Các cơ quan chịu trách nhiệm thực hiện triển khai chương trình Chuẩn hóa dữ liệu...
# [668/737] Query: Người dùng gửi yêu cầu cấp Tài khoản ĐKKD nhưng bị từ chối thì phải làm thế nào?...
# [669/737] Query: Bạn Văn Lộc cho biết:
# Tôi là học viên năm cuối hệ đại học chính quy trong Công a...
# [670/737] Query: Những việc thừa phát lại không được làm...
# [671/737] Query: Nội dung hợp tác quốc tế về công đoàn được quy định thế nào?
# ...
# [672/737] Query: Ông Văn Hưng (Bình Định) đăng ký hộ kinh doanh cá thể, ngành nghề kinh doanh là ...
# [673/737] Query: Vụ triệt phá hàng loạt tụ điểm 'bay lắc" ở Gia Lai: Khởi tố 84 đối tượng...
# [674/737] Query:  Bộ Công an có trách nhiệm thế nào với phòng thủ dân sự?...
# [675/737] Query: Theo quy định hiện hành, đăng ký nghĩa vụ quân sự lần đầu ở đâu?...
# [676/737] Query: Lao động nữ phá thai được hưởng chế độ thai sản thế nào?
# ...
# [677/737] Query: Người buộc đối tượng bảo trợ xã hội lao động nặng nhọc, độc hại, nguy hiểm bị ph...
# [678/737] Query: OpenAI bùng nổ doanh thu nửa đầu năm 2025...
# [679/737] Query: Những việc công chứng viên không được làm...
# [680/737] Query: Kính gửi Quý Cơ quan, chúng tôi bên Công ty TNHH Quốc Tế Cao Nguyên Xanh xin hỏi...
# [681/737] Query: TPHCM: Dự kiến chi 617 tỷ đồng hỗ trợ học phí cho học sinh ngoài công lập...
# [682/737] Query: Xin hỏi, sinh viên ngoại tỉnh đến Hà Nội học có cần khai báo tạm vắng không?
# ...
# [683/737] Query: Thời điểm xác lập quyền sở hữu nhà ở theo quy định mới thế nào?...
# [684/737] Query: Nhạc sĩ TPHCM về nguồn...
# [685/737] Query: Bà M.N.P sinh sống và làm việc tại tỉnh Tây Ninh nhưng được cấp chứng chỉ hành n...
# [686/737] Query: Xin hỏi, khi nào thì chính quyền được cưỡng chế thực hiện quyết định thu hồi đất...
# [687/737] Query: Bạn đọc Trần Khôi Nguyên ở thị trấn Phan Rí Cửa, huyện Tuy Phong, tỉnh Bình Thuậ...
# [688/737] Query: Xin hỏi, theo quy định mới, người mắc bệnh trầm cảm có thuộc đối tượng bắt buộc ...
# [689/737] Query: Bí thư Thành ủy TPHCM Trần Lưu Quang khảo sát trung tâm hành chính công phường đ...
# [690/737] Query: Người lao động nước ngoài làm việc tại Việt Nam có phải tham gia BHYT không?...
# [691/737] Query: Hồ sơ hưởng BHXH 1 lần...
# [692/737] Query: Vụ xe dâu dừng giữa đường chụp ảnh: Khi nào bị phạt hành chính, hình sự?...
# [693/737] Query: Cựu Tổng Giám đốc SJC Lê Thuý Hằng lãnh án 25 năm tù...
# [694/737] Query: Trải nghiệm Galaxy Tab S11 Ultra 5G: bước chuyển mình của tablet AI...
# [695/737] Query: Bà Thị Ngọc Anh là bác sĩ y học dự phòng, chưa có giấy phép hành nghề, đã tốt ng...
# [696/737] Query: Cách nào làm sổ đỏ khi mua bán đất giấy tờ tay?...
# [697/737] Query: thời hạn của giấy phép lao động tối đa là bao nhiêu năm? Giấy phép lao động sẽ b...
# [698/737] Query: Khoảng 20 triệu người được miễn phí khám sức khỏe định kỳ hàng năm...
# [699/737] Query: Tôi có thể mua dữ liệu về báo cáo tài chính của nhiều doanh nghiệp cùng một lúc ...
# [700/737] Query: “Về... ở luôn” với bánh bông lan...
# [701/737] Query: Đất có sổ đỏ là gì?
# ...
# [702/737] Query: Một cài đặt mặc định trên Windows 11 đang âm thầm 'giết chết' ổ SSD...
# [703/737] Query: Thời điểm nghỉ hưu...
# [704/737] Query: Tái vi phạm “vẽ bệnh, moi tiền”, Phòng khám đa khoa Tháng Tám bị đình chỉ hoạt đ...
# [705/737] Query: Điều kiện để cha mẹ nuôi được tính là người phụ thuộc...
# [706/737] Query:  Hỏi: Đề nghị tòa soạn cho biết, chức năng và nhiệm vụ của lực lượng kiểm tra xe...
# [707/737] Query: Nợ toàn cầu tăng kỷ lục...
# [708/737] Query: Xin hỏi, theo quy định của Luật Đất đai 2024, thì nguyên tắc và căn cứ định giá ...
# [709/737] Query: Hiện tại chúng tôi đã có kết quả chấp thuận hồ sơ đăng ký doanh nghiệp được gửi ...
# [710/737] Query: Đồng chí Trần Quang Lâm giữ chức Giám đốc Sở Xây dựng TPHCM...
# [711/737] Query: Hồ sơ đăng ký thường trú cho Việt kiều...
# [712/737] Query: Giám đốc Sở GD-ĐT TPHCM yêu cầu trường ngoài công lập tăng cường gắn kết với trư...
# [713/737] Query: Người lao động có thể nhận bảo hiểm thất nghiệp bao nhiêu lần?...
# [714/737] Query: Dấu hiệu nhiều tội danh vụ 80 thanh niên hỗn chiến trên quốc lộ...
# [715/737] Query: Trợ cấp mai táng...
# [716/737] Query: Thủ tướng: Hải Phòng phải nhìn xa, trông rộng, nghĩ sâu, làm lớn...
# [717/737] Query: Bạn đọc Vũ Minh Tuấn ở xã Hòa Bình, huyện Bình Gia, tỉnh Lạng Sơn, hỏi: Việc sử ...
# [718/737] Query: Tôi có thể xem báo cáo tài chính của tất cả các doanh nghiệp được không?...
# [719/737] Query: "Tử chiến trên không" dẫn đầu phòng vé, "Mưa đỏ" sắp đạt 700 tỷ đồng...
# [720/737] Query: Chào anh/ chị, cho em hỏi hồ sơ xin cấp thẻ ABTC cho doanh nhân Lê Thanh Tuyền t...
# [721/737] Query: Công ty của ông Huy (TPHCM) có 100% vốn Nhà nước.
# Ông Huy hỏi, công ty ông có đư...
# [722/737] Query: Xin hỏi, độ tuổi được ưu tiên khám bệnh, chữa bệnh là bao nhiêu?...
# [723/737] Query: Người lao động nước ngoài tại công ty của bà Thị Thanh Hiền cung cấp cho công ty...
# [724/737] Query: Sớm công bố phương án tuyển sinh đại học năm 2026...
# [725/737] Query: Để được giảm tiền thuê đất phải nộp của năm 2025, cần phải thực hiện thủ tục gì?...
# [726/737] Query: cảnh sát giao thông phải làm những công việc gì khi tuần tra, kiểm soát?
# ...
# [727/737] Query: Chằng buộc đồ trên nóc ô tô sẽ bị CSGT xử phạt?...
# [728/737] Query: Doanh nghiệp có thể tự đối chiếu, kiểm tra thông tin đăng ký doanh nghiệp của mì...
# [729/737] Query: Bắt giữ giám đốc chi nhánh ngân hàng liên quan đường dây “tín dụng đen”...
# [730/737] Query: Va chạm với xe tải, hai thanh niên đi xe máy tử vong...
# [731/737] Query: Trình độ chuẩn được đào tạo của giáo viên các cấp được quy định thế nào?
# ...
# [732/737] Query: Vụ sinh viên trường FPT hành hung bạn đổ máu: Có bị truy cứu hình sự?
#
# Trong vụ ...
# [733/737] Query: Cần Thơ: Khám sàng lọc bệnh tim bẩm sinh cho trẻ em...
# [734/737] Query: Vụ sai phạm đất đai ở huyện Vĩnh Thạnh (Bình Định): 21 cán bộ, đảng viên bị xem ...
# [735/737] Query: Người nước ngoài tại Việt Nam không khai báo tạm trú có thể bị trục xuất...
# [736/737] Query: Trường trung cấp tuyển sinh sai đối tượng học trình độ trung cấp thì bị phạt như...
# [737/737] Query: Đăng bài quảng cáo "bao đậu" bằng lái xe, lừa đảo 200 triệu đồng...
# ==== SUMMARY ====
# FAISS-only MRR@5 = 0.351628, nDCG@5 = 0.269844
# RERANKER (BAAI/bge-reranker-v2-m3) MRR@5 = 0.396766, nDCG@5 = 0.321516
